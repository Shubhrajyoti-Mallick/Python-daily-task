# %% [markdown]
# **Basic Class & Object (1-8)**
# 1. Create a class Student with instance attributes name and age. Create two objects
# and print their details.

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def show_details(self):
        print("Name:",self.name)
        print("age:",self.age)
s1=Student("shubhra",16)
s2=Student("Monu",10)
s1.show_details()
s2.show_details()
# Out:
# Name: shubhra
# age: 16
# Name: Monu
# age: 10

# %% [markdown]
# 2.2. Define class Car with attributes brand, model, and year. Create an object and
# display all attributes.

# %%
class Car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year
    def display(self):
        print(f"brand:{self.brand}")
        print(f"model:{self.model}")
        print(f"year:{self.year}")
car=Car("toyota","toyota31",2001)
car.display()
# Out:
# brand:toyota
# model:toyota31
# year:2001

# %% [markdown]
# 3. Create class Book with attributes title, author, price. Add a method display_info().

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
    def display_info(self):
        print(f"Book title : {self.title}")
        print(f"Book author: {self.author}")
        print(f"Book price:{self.price}")
book=Book("power of subconcious mind","sk.minu",280)
book.display_info()
# Out:
# Book title : power of subconcious mind
# Book author: sk.minu
# Book price:280

# %% [markdown]
# 4. Create class Employee with attributes emp_id, name, salary. Create 3 objects.

# %%
class Employee:
     def __init__(self,emp_id,name,salary):
         self.emp_id=emp_id
         self.name=name
         self.salary=salary
     def show(self):
         print(f"employee id:{self.emp_id}")
         print(f"name:{self.name}")
         print(f"salary:{self.salary}")
employee1=Employee("ABCD9","rushikesh",2000)
employee2=Employee("ABCD8","rishikesh",12000)
employee3=Employee("ABCD7","rimishikesh",22000)
employee1.show()
print("*"*20)
employee2.show()
print("*"*20)
employee3.show()
print("*"*20)
# Out:
# employee id:ABCD9
# name:rushikesh
# salary:2000
# ********************
# employee id:ABCD8
# name:rishikesh
# salary:12000
# ********************
# employee id:ABCD7
# name:rimishikesh
# salary:22000
# ********************

# %% [markdown]
# 5. Write a class Mobile with attributes brand, price, color. Print object using __str__
# method.
# **__str__ is a special inbuilt method  all called magic method or dunder method which is automatically  called when we print the  object using using Print().it always return string object**

# %%
class Mobile:
    def  __init__(self,brand,price,color):
        self.brand=brand
        self.price=price
        self.color=color
    def __str__(self):
        return f"\n brand:{self.brand}\n price:{self.price}\n color:{self.color}"
mobile=Mobile("apple",100000,"orange")
print(mobile)
# Out:
#  brand:apple
#  price:100000
#  color:orange

# %% [markdown]
# 6. Create class Rectangle with attributes length and width. Add method to calculate
# area.

# %%
class Rectangle:
   def __init__(self,length,width):
       self.length=length
       self.width=width
   def calculate_area(self):
       print(f"area: {self.length*self.width}")
rectangle= Rectangle(12,10)
rectangle.calculate_area()
# Out:
# area: 120

# %% [markdown]
# 7. Define class Person with attributes name and city. Create object and change city
# value.

# %%
class Person:
    def __init__(self,name,city):
        self.name=name
        self.city=city
person=Person("shubhra","bbsr")
person.city="bhdrak"
print("city:",person.city)
# Out:
# city bhdrak

# %% [markdown]
# 8.Create class Laptop and show how to create multiple objects with different values.

# %%
class Laptop:
    def __init__(self,model,price,brand):# constructor to initialze the model, brand and price of laptop
        self.model=model
        self.price=price
        self.brand=brand
    def display(self):# a  method named diplay is created to diplay the  details of laptop
        print(f"model:{self.model}")
        print(f"price: Rs{self.price}")
        print(f"brand: {self.brand}")
laptop=Laptop("asus expertbook",50000,"asus")# object1  of class laptop is created with argument
laptop1=Laptop("vivobook",70000,"asus")#object1  of class laptop is created with argument 
laptop2=Laptop("1k098",76000,"dell")#object2  of class laptop is created with argument 
laptop.display()
print("-"*30)
laptop1.display()
print("-"*30)
laptop2.display()
print("-"*30)
# method display is called through object to diplay all details of  laptop object
# Out:
# model:asus expertbook
# price: Rs50000
# brand: asus
# ------------------------------
# model:vivobook
# price: Rs70000
# brand: asus
# ------------------------------
# model:1k098
# price: Rs76000
# brand: dell
# ------------------------------

# %% [markdown]
# **Class Attributes (9-15)**
# Create class Student with class attribute school_name = "City School". Print it
# using class name and object.

# %%
class Student:
    # Class attribute shared by all Student objects
    school_name = "City School"

# Create an object
student = Student()

# Print using the class name
print(Student.school_name)

# Print using the object
print(student.school_name)
# Out:
# City School
# City School

# %% [markdown]
# 10. Create class Bank with class attribute bank_name. Change its value using class
# name and check effect on objects.

# %%
class Bank:
    bank_name="SBI"
bank1=(Bank)
bank2=(Bank)
print("before changing")
print(bank1.bank_name)
print(bank2.bank_name)
Bank="icic"
print("after changing")
print(bank1.bank_name)
print(bank2.bank_name)
# Out:
# before changing
# SBI
# SBI
# after changing
# SBI
# SBI

# %% [markdown]
# 11. Define class Counter with class attribute count = 0. Add method to increment
# count.

# %%
class  Counter:
    count=0
    def increment(self):#method to increment the count 
        Counter.count+=1
        print(f"count {Counter.count}")
counter=Counter()#object counter of  the Class Counter 
counter2=Counter()
counter.increment()
counter2.increment()
# Out:
# count 1
# count 2

# %% [markdown]
#                      **OR**

# %%
class Counter:
    count=0 # class atribute shared by all object
    @classmethod 
    def increment(cls):# class method  to access class atribute
       cls.count+=1
       return cls.count
        
counter=Counter()
Counter.increment() #  class method increment is called through  Class 
counter.increment()# class method increment can also  be called through object
# Out:
# 2

# %% [markdown]
# 12. Create class Employee with class attribute company = "ABC Corp". Show that all
# objects share it.

# %%
class Employee:
    company="ABC corp"# class atribute  shared by all object
emp1=Employee()# object one of class emloyee
emp2=Employee()#object 2 of class emloyee
print(emp1.company)
print(emp2.company)# both  object access the same class atribute
# Out:
# ABC corp
# ABC corp

# %% [markdown]
# 13. In class Circle, add class attribute pi = 3.14. Use it in area calculation method.

# %%
class Circle:
    pi=3.14
    def __init__(self,radius):# without the extra method to calculate area
        
       self.radius=radius
       print(f"area {Circle.pi*self.radius*self.radius}")
circle=Circle(5)
# Out:
# area 78.5

# %%
class Circle:
    pi=3.14
    def __init__(self,radius):
        self.radius=radius
    def calculate_area(self):
        return f" area of circle: {Circle.pi*pow(self.radius,2)}"
        
circle=Circle(5)
print(circle.calculate_area())
# Out:
#  area of circle: 78.5

# %% [markdown]
# 14.. Create class MathUtils with class attribute version = "1.0". Print it.

# %%
class MathUtils:
    version="1.0"
    @classmethod
    def Version(cls):
        return cls.version
mathUtils=MathUtils()
print(mathUtils.Version())# class method is called using object
print(MathUtils.Version()) #class method is called using class
print(mathUtils.version)# class atribute  is printed or called using object
print(MathUtils.version) # class atributed is printed usng class name
# Out:
# 1.0
# 1.0
# 1.0
# 1.0

# %% [markdown]
# 15.. Show difference between class attribute and instance attribute with example of
# class Player.

# %%
class  Player:
    name="shubhra"# class atribute  defined under class can be shared by all object
    game="football"
    def  display(self,game_name):# instance method with  one argument game_name
        self.game_name=game_name#instance atribute declared under  instance method
        print(self.game_name)
player =Player()
player.display("cricket")#  instance attribute can be accessed using  instance method
player.game_name # instance attribute is accessed using  object    
print(Player.name)# class atribute is called class name
print(Player.game)# class attribute is called using object name
# here  class atribute can be accessed using both class name and object name while   instance attribute can only be  called using instance  method or  object
#  class atribute can be accessed  using aclass method having  default parameter  cls while instance method  can be accesed using method having default parameter  self.
# class atribute can also be accessed through instancemethod using class name while intance method cannont be accessed in class method
# Out:
# cricket
# shubhra
# football

# %% [markdown]
# **Private Attributes (16-22)**

# %% [markdown]
# 23. Create class Student with private __marks. Add getter and setter methods.

# %%
class Student:
    def __init__(self,marks):#constructor  to initialize private atribute
        self.__mark=marks
    def getmarks(self):# getter method creted to retrive current marks
        return self.__mark
    def setmarks(self,marks):# setter method to update the marks
        if marks>=0:
            self.__mark=marks
            print(f"marks:{self.__mark}")
        else:
            print("enter  valid marks")
student=Student(45)# object student class Student created
print("current marks is:",student.getmarks())#getter method getmarks() called and printed to retrive current marks
student.setmarks(34)#setter method called to update the marks
print ("updated mark is :",student.getmarks())# getter method  getmarks() called and printed to verify the updated marks
# Out:
# current marks is: 45
# marks:34
# updated mark is : 34

# %% [markdown]
# In class BankAccount, add getter and setter for private __balance with validation.

# %%
class BankAccount:
    def __init__(self, balance):# constructor to initialize private atribute balance
        self.__balance=balance
    def getbalance(self):# getter method to  retrive  and read current balance
        return self.__balance
    def setbalance(self,balance):# setter method tomupdate the balance
        if balance>=0:
            self.__balance=balance
            print("balance updated :",self.__balance)
        else:
            print("invalid balance")
bankaccount=BankAccount(456)# object bankaccount of class Bank Account is created
bankaccount.getbalance()# getter method is called through object to read currentb balance
bankaccount.setbalance(450)# setter methhod is called through objcet to update the current balance
bankaccount.getbalance()# again  getter method to  verify the  updated balance
# Out:
# balance updated : 450
# 450

# %% [markdown]
# 25. Create class Employee with private __salary. Setter should not allow value below
# 5000.

# %%
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def getsalary(self):
        return self.__salary
    def setsalary(self,salary):
        if salary>=5000:
            self.__salary=salary
            print(f" salary updated successfully:{self.__salary}")
            
        else:
            print(" salary should not be less than 5000")
employee=Employee(700)
print(employee.getsalary())
employee.setsalary(5000)
print(employee.getsalary())
# Out:
# 700
#  salary updated successfully:5000
# 5000

# %% [markdown]
# 26. Define class Temperature with private __celsius. Add getter and setter with
# conversion.

# %%
class Temprature:
    def __init__(self,celcius):
        self.__celcius=celcius
    def getcelcius(self):
        return self.__celcius
    def setcelcius(self,celcius):
        if celcius>=-273.25:
            self.__celcius=celcius
            print(" updated temprature is :", self.__celcius)
        else:
            print("enter valid temprature")
    def getfarenhite(self):
        farenhite_temprature=(self.__celcius*9/5+32)
        return farenhite_temprature
temprature=Temprature(43)
print(temprature.getcelcius())
temprature.setcelcius(456)
print(temprature.getcelcius())
temprature.getfarenhite()
# Out:
# 43
#  updated temprature is : 456
# 456
# 852.8

# %% [markdown]
# 27. Create class Person with private __age. Add setter with validation (age between
# 0-120).

# %%
class Person:
    def __init__(self,age):
        self.__age=age
    def getage(self):
        return  self.__age
    def setage(self,age):
        if age  in range(121):
            self.__age=age
            print(" updated age is",self.__age)
        else:
            print("invalid age")
person=Person(23)
person.getage()
person.setage(24)
person.getage()
# Out:
#  updated age is 24
# 24

# %% [markdown]
# 28.. In class Product, add getter and setter for private __price with discount logic.

# %%
class Product:
    def __init__(self,price):
        self.__price=price
    def getprice(self):
        return self.__price
    def setprice(self,price):
        if price>0:
            self.__price=price-(10/100*price)
            print('price',self.__price)
        else:
            print("enter valid price")
product=Product(45)
print(product.getprice())
product.setprice(56)
# Out:
# 45
# price 50.4

# %% [markdown]
# 29. Create class Mobile with private __price. Add setter that prints message on price
# change.

# %%
class Mobile:
    def __init__(self,price):# constructor for intilizing the private attribute attribute
        self.__price=price
    def getprice(self):# getter method to retrive  the private attribute
        return self.__price
    def setprice(self,price):#  setter to update  the private attribute
        if price>0:
            self.__price=price
            print(f"price updated successfully:Rs{self.__price}")
        else:
            print("invalid price ,price must be greater than zero")
mobile=Mobile(34000)# object  created of the class Mobile
print(mobile.getprice())#getter  method  to retrive the  current price
mobile.setprice(8000)#setter method called to update the price
print(mobile.getprice())# updated price is verified  through gettter method
# Out:
# 34000
# price updated successfully:Rs8000
# 8000

# %% [markdown]
# 30. Define class Rectangle with private __length and __width. Add getter/setter and
# area method.

# %%
class Rectangle:
    def __init__(self,length,width):
        self.__length=length
        self.__width=width
    def area(self):
        area=self.__length*self.__width
        print(f"area of rectange: {area}")
    def getlength(self):
        return self.__length
    def getwidth(self):
        return self.__width
    def setlength(self,length):
        if length>0:
            self.__length=length
            print("length",self.__length)

        else:
            print("enter valid length")
    def setwidth(self,width):
        if width>0:
            self.__width=width
            print("width",self.__width)
        else:
            print("enter valid length")
rectangle=Rectangle(23,10)
print(rectangle.getlength())
print(rectangle.getwidth())
rectangle.area()
rectangle.setwidth(5)
print(rectangle.getwidth())
# Out:
# 23
# 10
# area of rectange: 230
# width 5
# 5

# %% [markdown]
# **Hard Questions on OOP (with extra conditions in Update / Setter methods)**

# %% [markdown]
# 1. (Hard) Create class Employee with private attribute __salary. Add getter and
# setter with these conditions in setter:
# • Salary cannot be less than 5000.
# • Salary cannot be increased by more than 20% at once.
#
#
# • Keep track of last updated salary using class attribute. Add class method
# get_total_employees().

# %%
class Employee:
   def __init__(self,salary):
       self.__salary=salary
    def getsalary(self):
        retrun self.__salary
    def setsalary(self,salary):
        if salary>=5000:
            if salary!=salary+20/10:
                
            
                 self.__salary=salary
                 print("salary:",self.__salary)
            else:
                print("salary shoudd not be more than 20%")
        else:
            print("salary should not be less than 5000")
# Out:
#   File <string>:4
#     def getsalary(self):
#                         ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# 2. (Hard) Create class BankAccount with private __balance. Implement setter for
# balance with these rules:
# • Balance cannot go below minimum balance (1000).
# • If balance > 100000, give 5% bonus automatically.
# • Log every update (use a class list to store history). Add getter and class
# method to show total accounts created.

# %%
class BankAccount:
    account_created=0
    history=[]
    def __init__(self,balance):
        if balance>=1000:
            self.__balance=balance
            BankAccount.account_created+=1
            BankAccount.history.append(self.__balance)
        else:
            print("Initial balance cannot be below minimum balance (1000).")
            self.__balance=1000
            BankAccount.account_created+=1
            BankAccount.history.append(self.__balance)
        

    @classmethod
    def accountcreated(cls):
         return cls.account_created
    
    def get_balance(self):
        return self.__balance
    
    def set_balance(self, new_balance):
        # Rule: Balance cannot go below minimum balance (1000)
        if new_balance < 1000:
            print(f"Cannot set balance to {new_balance}. Minimum balance is 1000.")
            return # Exit the method without updating

        # Rule: If balance > 100000, give 5% bonus automatically
        if new_balance > 100000:
            self.__balance = new_balance + (0.05 * new_balance) # Using 0.05 for 5%
            print(f"Balance with 5% bonus is: {self.__balance}")
        else:
            self.__balance = new_balance
            print(f"Balance updated to: {self.__balance}")

        BankAccount.history.append(self.__balance)
bankaccount=BankAccount(100)
bankaccount.set_balance(3000)
BankAccount.history
BankAccount.accountcreated()
# Out:
# Initial balance cannot be below minimum balance (1000).
# Balance updated to: 3000
# 1
