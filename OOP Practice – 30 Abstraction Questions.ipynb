# %% [markdown]
# **Python OOP Practice – 30 Abstraction Questions
#
# Part A – Abstraction Without super() (1–15)**
# 1. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# A shape can have different formulas for area and perimeter. Therefore, create two abstract
# methods:
# • area()
# • perimeter()
# Create subclasses like Circle and Rectangle and implement both methods.

# %%
from abc import ABC,abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstracttmethod
    def perimeter(self):
        pass
class  Circle(Shape):
    pi=3.14
    def area(self,r):
        area=Circle.pi*r*r
        print("area   of circle is is :",area)
    def perimeter(self):
        perimeter=2*Circle.pi*r
        print("perimeter of circle is",perimeter)
class Rectangle(Shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        area=self.length*self.breadth
        print("area of rectangle is: ",area)
    def perimeter(self):
        perimeter=2(length+breadth)
        print("perimeter of rectangle is :",perimeter)
circle=Circle()
# Out:
# <>:25: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from abc import ABC,abstractmethod
# ----> 2 class Shape(ABC):
#       3     @abstractmethod
#       4     def area(self):
#       5         pass
#
# Cell In[4], line 6, in Shape()
#       3 @abstractmethod
#       4 def area(self):
#       5     pass
# ----> 6 @abstracttmethod
#       7 def perimeter(self):
#       8     pass
#
# NameError: name 'abstracttmethod' is not defined

# %% [markdown]
# 2.
# Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Every vehicle has common information like brand and fuel type, but different vehicles start
# and consume fuel differently.
# Create a constructor:
# __init__(self, brand, fuel_type)
# Store:
# • Brand
# • Fuel Type
# Create a normal method:
# display_vehicle()
# Create abstract methods:
# • start()
# • fuel_consumption(distance)
# Create the following subclasses
# ElectricCar
# • Use super() to initialize parent attributes.
# • Validate that the fuel type is "Electric".
# • Implement start().
# • Implement fuel_consumption(distance) using battery consumption.
# • Override display_vehicle() and call the parent version using super().
# PetrolCar
# • Use super() to initialize parent attributes.
# • Validate that the fuel type is "Petrol".
# • Implement start().
# • Implement fuel_consumption(distance) using petrol consumption.
# • Override display_vehicle() and reuse the parent method using super().
# Concepts Covered
# • Abstract Class
# • Constructor
# • Validation
# • Method Overriding
# • super()
# • Parent Method

# %%
from abc import ABC,abstractmethod
class Vechile(ABC):
    def __init__(self,brand,fuel_type):
        self.brand=brand
        self.fuel_type=fuel_type
    def  display_vechile(self):
        print("vechile brand",self.brand)
        print(f" fuel used by vechile:{self.fuel_type}")
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def fuel_consumption(self,distance):
        pass
class ElectricCar(Vechile):
     def __init__(self,brand,fuel_type):
        super.__init__(brand,fuel_type)
        self.brand=brand
        self.fueltype="electric"
     def start(self):
        print("electric car started")
     def  fuel_consumption(self,distance,battery_used):
        fuel_consumtion= battery_used/distance
        return fuel_consumption
     def  display_vechile(self):
        super.display_vechile(self)
        print("vechile brand",self.brand)
        print(f" fuel used by vechile:{self.fuel_type}")
class Petrolcar(Vechile):
     def __init__(self,brand,fuel_type):
        super.__init__(brand,fuel_type)
        self.brand=brand
        self.fueltype="petrol"
     def start(self):
        print("petrol car started")
     def  fuel_consumption(self,distance,petrol_used):
        fuel_consumtion= petrol_used/distance
        return fuel_consumption
     def  display_vechile(self):
        super.display_vechile(self)
        print("vechile brand",self.brand)
        print(f" fuel used by vechile:{self.fuel_type}")
electricar=ElectricCar("abc","hjui")
electriccar.diplay_vechile()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 43
#      41         print("vechile brand",self.brand)
#      42         print(f" fuel used by vechile:{self.fuel_type}")
# ---> 43 electricar=ElectricCar("abc","hjui")
#      44 electriccar.diplay_vechile()
#
# Cell In[17], line 17, in ElectricCar.__init__(self, brand, fuel_type)
#      16 def __init__(self,brand,fuel_type):
# ---> 17    super.__init__(brand,fuel_type)
#      18    self.brand=brand
#      19    self.fueltype="electric"
#
# TypeError: descriptor '__init__' requires a 'super' object but received a 'str'
