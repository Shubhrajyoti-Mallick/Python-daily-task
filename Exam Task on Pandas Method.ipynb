# %% [markdown]
# Part 1 — Inspect & Understand the Dataset
# Q1. Load the dataset
# Load messy_customer_analytics_2000x15.csv into a DataFrame called df.
# Then display the first 10 rows.
# Use: pd.read_csv(), head()

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\jyoti\Downloads\customer_analytics.csv")
print(df)
df.head(10)
# Out:
#       Customer_ID   Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55.0       44033.0       111350.85          772
# 1          101001  32.0      215546.0       254378.37          374
# 2          101069  23.0      226403.0       159975.42          668
# 3          101968  66.0       87824.0        295741.6          315
# 4          100530  67.0       31570.0       242423.78          370
# ...           ...   ...           ...             ...          ...
# 2035       101131  42.0       88530.0       153490.72          677
# 2036       101295  31.0      205738.0        270989.4          392
# 2037       100861  25.0      211994.0       160507.65          737
# 2038       101460  64.0       30105.0        32117.15          794
# 2039       101127  55.0      248332.0       274980.99          783
#
#       Tenure_Years         City    Segment Channel            Join_Date  \
# 0                3    Bangalore        SME   Agent  2022-08-15 00:00:00
# ...

# %% [markdown]
# Q2. Inspect the end of the dataset
# Display the last 15 rows.
# Use: tail()

# %%
df.tail(15)
# Out:
#       Customer_ID            Age Annual_Income Account_Balance Credit_Score  \
# 2025       100088           51.0      214004.0       173779.91          686
# 2026       101483  not_available      117573.0       261905.82          657
# 2027       100331           54.0      123511.0       280896.35          388
# 2028       101239           31.0      125500.0       189174.28          846
# 2029       100467            NaN      101619.0       279182.04          392
# 2030       100122           41.0      201611.0        40736.71          507
# 2031       101639           61.0      128850.0        266135.8          840
# 2032       101045           33.0       88037.0       129948.93          449
# 2033       101725           43.0      122756.0        36633.45          487
# 2034       101096           18.0      189232.0       235131.72          306
# 2035       101131           42.0       88530.0       153490.72          677
# ...

# %% [markdown]
# Q3. Random inspection
# Display 10 random records.
# Use: sample()

# %%
df.sample(10)
# Out:
#       Customer_ID   Age Annual_Income Account_Balance Credit_Score  \
# 1846       100564   NaN      221910.0        68608.32          724
# 972        101647  27.0      207779.0             NaN          331
# 739        100590  65.0      228532.0       109306.27          470
# 523        101101  32.0       28631.0       130925.88          624
# 902        101895     -      106768.0       171792.86          590
# 1620       101073   abc      145575.0       158617.33          768
# 1674       101698  74.0      130487.0        99599.49          836
# 455        101680  38.0           NaN       169821.49          351
# 1538       100838  36.0      156733.0        148050.3          431
# 86         101478  35.0      179324.0        13574.76          610
#
#       Tenure_Years       City    Segment Channel            Join_Date Active  \
# 1846            13        NaN  Corporate  Online  2024-02-06 00:00:00    Yes
# ...

# %% [markdown]
# Q4. Dataset audit
# Use info() to identify:
# • Number of rows
# • Number of columns
# • Columns with missing values
# • Columns having incorrect/object datatypes
# Use: info()

# %% [markdown]
# df.info()

# %% [markdown]
# Q5. Missing-value audit
# Calculate the number of missing values in every column.
# Then verify the result using both:
# isnull()
# and
# isna()

# %%
print(df.isnull().sum())
print(df.isnull().sum())
# Out:
# Customer_ID             0
# Age                    83
# Annual_Income         107
# Account_Balance       128
# Credit_Score            4
# Tenure_Years            0
# City                   81
# Segment               105
# Channel                 0
# Join_Date             102
# Active                 59
# Risk_Level              0
# Monthly_Spend         109
# Transactions            2
# Satisfaction_Score     85
# dtype: int64
# Customer_ID             0
# Age                    83
# Annual_Income         107
# Account_Balance       128
# Credit_Score            4
# Tenure_Years            0
# City                   81
# Segment               105
# Channel                 0
# Join_Date             102
# Active                 59
# Risk_Level              0
# Monthly_Spend         109
# Transactions            2
# Satisfaction_Score     85
# dtype: int64

# %% [markdown]
# Part 2 — Detect & Fix Data Quality Problems
# Q6. Duplicate investigation
# Find how many duplicate rows exist.
# Do not remove them yet.
# Use: duplicated()

# %%
print(df.duplicated().sum())# to find  the no of duplicate rows
# Out:
# 40

# %% [markdown]
# Q7. Remove duplicates
# Remove all duplicate records and store the cleaned result back into df.
# Then verify that duplicates no longer exist.
# Use: drop_duplicates(), duplicated()

# %%
df=df.drop_duplicates()
print(df)
df.duplicated()
# Out:
#       Customer_ID   Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55.0       44033.0       111350.85          772
# 1          101001  32.0      215546.0       254378.37          374
# 2          101069  23.0      226403.0       159975.42          668
# 3          101968  66.0       87824.0        295741.6          315
# 4          100530  67.0       31570.0       242423.78          370
# ...           ...   ...           ...             ...          ...
# 2035       101131  42.0       88530.0       153490.72          677
# 2036       101295  31.0      205738.0        270989.4          392
# 2037       100861  25.0      211994.0       160507.65          737
# 2038       101460  64.0       30105.0        32117.15          794
# 2039       101127  55.0      248332.0       274980.99          783
#
#       Tenure_Years         City    Segment Channel            Join_Date  \
# 0                3    Bangalore        SME   Agent  2022-08-15 00:00:00
# ...

# %% [markdown]
# Q8. Numeric column investigation
# Select only numeric columns.
# Identify which columns are currently numeric and which potentially numeric columns have
# become object because of invalid values.
# Use: select_dtypes()

# %%
num=df.select_dtypes(["number"])
print("currently numeric")
print(num)
print("potentially numeric columns have become object because of invalid values.")
obj=df.select_dtypes(include=["object"])
print(obj)
# Out:
# currently numeric
#       Customer_ID  Tenure_Years  Satisfaction_Score
# 0          101317             3                 3.1
# 1          101001             8                 8.2
# 2          101069            12                 6.3
# 3          101968            14                 9.7
# 4          100530             4                 3.7
# ...           ...           ...                 ...
# 2035       101131            12                 8.6
# 2036       101295             8                 2.6
# 2037       100861             8                 1.3
# 2038       101460             8                 9.3
# 2039       101127             6                 3.1
#
# [2000 rows x 3 columns]
# potentially numeric columns have become object because of invalid values.
#        Age Annual_Income Account_Balance Credit_Score         City    Segment  \
# 0     55.0       44033.0       111350.85          772    Bangalore        SME
# ...

# %% [markdown]
# Q9. Fix Age
# The Age column contains:
# • Valid numbers
# • Missing values
# • Invalid text such as unknown, N/A, etc.
# Convert Age into a proper numeric column.
# Invalid values should become missing values.
# Then fill missing Age values using the median age.
# Use: pd.to_numeric(), median(), fillna()

# %%
df["Age"]=pd.to_numeric(df["Age"],errors="coerce")
print(df["Age"])
print("finding meadian of Age")
median=df["Age"].median()
print(median)
print("filling missing value of age with  median")
df["Age"]=df["Age"].fillna(median)
print(df["Age"])
# Out:
# 0       55.0
# 1       32.0
# 2       23.0
# 3       66.0
# 4       67.0
#         ...
# 2035    42.0
# 2036    31.0
# 2037    25.0
# 2038    64.0
# 2039    55.0
# Name: Age, Length: 2000, dtype: float64
# finding meadian of Age
# 47.0
# filling missing value of age with  median
# 0       55.0
# 1       32.0
# 2       23.0
# 3       66.0
# 4       67.0
#         ...
# 2035    42.0
# 2036    31.0
# 2037    25.0
# 2038    64.0
# 2039    55.0
# Name: Age, Length: 2000, dtype: float64

# %% [markdown]
# Q10. Fix Annual Income
# Clean Annual_Income.
# Requirements:
# 1. Convert invalid values to missing.
# 2. Convert the column to a numeric datatype.
# 3. Calculate the median.
# 4. Fill missing values using the median.
# Use: pd.to_numeric(), median(), fillna(), astype()

# %%
df["Annual_Income"]=pd.to_numeric(df["Annual_Income"],errors="coerce")
print(df["Annual_Income"])
print("calculating median of Annual_Income")
median=df["Annual_Income"].median()
print(median)
print("  missing values is filled  using  median")
df["Annual_Income"]=df["Annual_Income"].fillna(median)
print(df["Annual_Income"])
# Out:
# 0        44033.0
# 1       215546.0
# 2       226403.0
# 3        87824.0
# 4        31570.0
#           ...
# 2035     88530.0
# 2036    205738.0
# 2037    211994.0
# 2038     30105.0
# 2039    248332.0
# Name: Annual_Income, Length: 2000, dtype: float64
# calculating median of Annual_Income
# 139914.0
#   missing values is filled  using  median
# 0        44033.0
# 1       215546.0
# 2       226403.0
# 3        87824.0
# 4        31570.0
#           ...
# 2035     88530.0
# 2036    205738.0
# 2037    211994.0
# 2038     30105.0
# 2039    248332.0
# Name: Annual_Income, Length: 2000, dtype: float64

# %%
Part 3 — Numerical Cleaning
Q11. Clean Account Balance
The Account_Balance column contains invalid strings and missing values.
Clean the column and replace missing values with the mean Account Balance.
Use:
• pd.to_numeric()
• mean()
• fillna()

# %%
df["Account_Balance"]=pd.to_numeric(df["Account_Balance"],errors="coerce")
print(df["Account_Balance"])
mean=df["Account_Balance"].mean()
print("mean of Account balance:")
print(mean)
print("filling missing values with mean")
df["Account_Balance"]=df["Account_Balance"].fillna(mean)
print(df["Account_Balance"])
# Out:
# 0       111350.85
# 1       254378.37
# 2       159975.42
# 3       295741.60
# 4       242423.78
#           ...
# 2035    153490.72
# 2036    270989.40
# 2037    160507.65
# 2038     32117.15
# 2039    274980.99
# Name: Account_Balance, Length: 2000, dtype: float64
# mean of Account balance:
# 151344.55801855895
# filling missing values with mean
# 0       111350.85
# 1       254378.37
# 2       159975.42
# 3       295741.60
# 4       242423.78
#           ...
# 2035    153490.72
# 2036    270989.40
# 2037    160507.65
# 2038     32117.15
# 2039    274980.99
# Name: Account_Balance, Length: 2000, dtype: float64

# %% [markdown]
# Q12. Clean Credit Score
# Clean Credit_Score.
# Invalid values should become missing.
# Then replace missing values with the median Credit Score.
# Finally convert the column to integer.
# Use:
# • pd.to_numeric()
# • median()
#
# • fillna()
# • astype()

# %%
df["Credit_Score"]=pd.to_numeric(df["Credit_Score"],errors="coerce")
print("filling invalid values to missing")
print(df["Credit_Score"])
print("finding median of credit score")
median=df["Credit_Score"].median()
print(median)
print("replacing missing values with median score")
df["Credit_Score"]=df["Credit_Score"].fillna(median)
print(df["Credit_Score"])
print(" converting columns to integer")
df["Credit_Score"]=df["Credit_Score"].astype("int")
print(df["Credit_Score"])
# Out:
# filling invalid values to missing
# 0       772.0
# 1       374.0
# 2       668.0
# 3       315.0
# 4       370.0
#         ...
# 2035    677.0
# 2036    392.0
# 2037    737.0
# 2038    794.0
# 2039    783.0
# Name: Credit_Score, Length: 2000, dtype: float64
# finding median of credit score
# 570.5
# replacing missing values with median score
# 0       772.0
# 1       374.0
# 2       668.0
# 3       315.0
# 4       370.0
#         ...
# 2035    677.0
# 2036    392.0
# 2037    737.0
# 2038    794.0
# 2039    783.0
# Name: Credit_Score, Length: 2000, dtype: float64
#  converting columns to integer
# 0       772
# 1       374
# 2       668
# 3       315
# 4       370
#        ...
# 2035    677
# 2036    392
# 2037    737
# 2038    794
# 2039    783
# Name: Credit_Score, Length: 2000, dtype: int64

# %% [markdown]
# Q13. Clean Monthly Spend
# Clean Monthly_Spend.
# Then:
# • Convert it to numeric.
# • Replace invalid values.
# • Replace missing values using the median.
# • Make sure the final column is numeric.

# %%
df["Monthly_Spend"]=pd.to_numeric(df["Monthly_Spend"],errors="coerce")
print(df["Monthly_Spend"])
median=df["Monthly_Spend"].median()
print("finding median of Monthly_Spend :")
print(median)
print("replacing missing value  with median")
df["Monthly_Spend"]=df["Monthly_Spend"].fillna(median)
print(df["Monthly_Spend"])
# Out:
# 0       23066.19
# 1            NaN
# 2       28536.34
# 3       12869.71
# 4       34163.02
#           ...
# 2035     8455.42
# 2036    34087.69
# 2037    26518.74
# 2038    20943.11
# 2039    48511.32
# Name: Monthly_Spend, Length: 2000, dtype: float64
# finding median of Monthly_Spend :
# 24625.17
# replacing missing value  with median
# 0       23066.19
# 1       24625.17
# 2       28536.34
# 3       12869.71
# 4       34163.02
#           ...
# 2035     8455.42
# 2036    34087.69
# 2037    26518.74
# 2038    20943.11
# 2039    48511.32
# Name: Monthly_Spend, Length: 2000, dtype: float64

# %% [markdown]
# Q14. Clean Transactions
# The Transactions column contains invalid strings.
# Convert it to numeric and replace invalid values with the median number of transactions.
# Then convert the final column to integer.

# %%
df["Transactions"]=pd.to_numeric(df["Transactions"],errors="coerce")
print("converting the values to numeric values and invalid  values to  missing values")
print(df["Transactions"])
print(" finding the median of  Transactions")
median=df["Transactions"].median()
print(median)
print(" replacing missing values with median")
df["Transactions"]=df["Transactions"].fillna(median)
print(df["Transactions"])
print("converting the column to integer")
df["Transactions"]=df["Transactions"].astype("int")
print(df["Transactions"])
# Out:
# converting the values to numeric values and invalid  values to  missing values
# 0       135.0
# 1       106.0
# 2       146.0
# 3       115.0
# 4        94.0
#         ...
# 2035    119.0
# 2036    134.0
# 2037     87.0
# 2038    107.0
# 2039    119.0
# Name: Transactions, Length: 2000, dtype: float64
#  finding the median of  Transactions
# 76.0
#  replacing missing values with median
# 0       135.0
# 1       106.0
# 2       146.0
# 3       115.0
# 4        94.0
#         ...
# 2035    119.0
# 2036    134.0
# 2037     87.0
# 2038    107.0
# 2039    119.0
# Name: Transactions, Length: 2000, dtype: float64
# converting the column to integer
# 0       135
# 1       106
# 2       146
# 3       115
# 4        94
#        ...
# 2035    119
# 2036    134
# 2037     87
# 2038    107
# 2039    119
# Name: Transactions, Length: 2000, dtype: int64

# %% [markdown]
# Q15. Clean Satisfaction Score
# Clean Satisfaction_Score.
# Replace missing/invalid values using the mean Satisfaction Score.
# Then convert the column to float.

# %%
df["Satisfaction_Score"]=pd.to_numeric(df["Satisfaction_Score"],errors="coerce")
print(df["Satisfaction_Score"])
print('finding mean of this column')
mean=df["Satisfaction_Score"].mean()
print(mean)
print('Replace missing/invalid values using the mean Satisfaction Score')
df["Satisfaction_Score"]=df["Satisfaction_Score"].fillna(mean)
print(df["Satisfaction_Score"])
print("converting the column to float")
df["Satisfaction_Score"]=df["Satisfaction_Score"].astype("float")
print(df["Satisfaction_Score"])
# Out:
# 0       3.1
# 1       8.2
# 2       6.3
# 3       9.7
# 4       3.7
#        ...
# 2035    8.6
# 2036    2.6
# 2037    1.3
# 2038    9.3
# 2039    3.1
# Name: Satisfaction_Score, Length: 2000, dtype: float64
# finding mean of this column
# 5.605416666666668
# eplace missing/invalid values using the mean Satisfaction Score
# 0       3.1
# 1       8.2
# 2       6.3
# 3       9.7
# 4       3.7
#        ...
# 2035    8.6
# 2036    2.6
# 2037    1.3
# 2038    9.3
# 2039    3.1
# Name: Satisfaction_Score, Length: 2000, dtype: float64
# converting the column to float
# 0       3.1
# 1       8.2
# 2       6.3
# 3       9.7
# 4       3.7
#        ...
# 2035    8.6
# 2036    2.6
# 2037    1.3
# 2038    9.3
# 2039    3.1
# Name: Satisfaction_Score, Length: 2000, dtype: float64

# %%
Part 4 — Date Cleaning
Q16. Investigate Join_Date
Inspect the Join_Date column.
Identify the problems caused by:
• Missing dates
• Different date formats
• Invalid date strings

Do not clean it yet.

# %%
print(" inspecting join date column")
print(df["Join_Date"])
print(" identifying  number missing dates of column")
print(df["Join_Date"].isnull().sum())
print(" diffrent date format")
print(df["Join_Date"].dtype)
print("invalid date string")
print(df["Join_Date"].unique())
# Out:
#  inspecting join date column
# 0       2022-08-15 00:00:00
# 1       2025-01-11 00:00:00
# 2       2024-08-01 00:00:00
# 3       2021-05-15 00:00:00
# 4       2026-02-03 00:00:00
#                ...
# 2035    2021-07-10 00:00:00
# 2036    2025-07-05 00:00:00
# 2037    2022-10-17 00:00:00
# 2038    2023-08-26 00:00:00
# 2039                    NaN
# Name: Join_Date, Length: 2000, dtype: object
#  identifying  number missing dates of column
# 100
#  diffrent date format
# object
# invalid date string
# ['2022-08-15 00:00:00' '2025-01-11 00:00:00' '2024-08-01 00:00:00' ...
#  '2025-09-10 00:00:00' '2022-10-17 00:00:00' '2023-08-26 00:00:00']

# %% [markdown]
# Q17. Convert Join_Date
# Convert Join_Date into a proper Pandas datetime column.
# Any invalid dates should become missing values.
# Use: pd.to_datetime()

# %%
df["Join_Date"]=pd.to_datetime(df["Join_Date"],errors="coerce")
print(df["Join_Date"])
# Out:
# 0      2022-08-15
# 1      2025-01-11
# 2      2024-08-01
# 3      2021-05-15
# 4      2026-02-03
#           ...
# 2035   2021-07-10
# 2036   2025-07-05
# 2037   2022-10-17
# 2038   2023-08-26
# 2039          NaT
# Name: Join_Date, Length: 2000, dtype: datetime64[ns]

# %% [markdown]
# Q18. Handle missing dates
# After conversion, find how many missing dates remain.
# Then replace missing dates appropriately using a reasonable date-based strategy.

# %%
df["Join_Date"]=pd.to_datetime(df["Join_Date"],errors="coerce")
print(" number of missing values:")
print(df["Join_Date"].isnull().sum())
print("replacing missing dates appropriately using a reasonable date-based strategy.")
median=df["Join_Date"].median()
print(f"median of this column is {median}")
print("filling the missing values with median")

df["Join_Date"].fillna(median)
# Out:
#  number of missing values:
# 125
# replacing missing dates appropriately using a reasonable date-based strategy.
# median of this column is 2023-08-24 00:00:00
# filling the missing values with median
# 0      2022-08-15
# 1      2025-01-11
# 2      2024-08-01
# 3      2021-05-15
# 4      2026-02-03
#           ...
# 2035   2021-07-10
# 2036   2025-07-05
# 2037   2022-10-17
# 2038   2023-08-26
# 2039   2023-08-24
# Name: Join_Date, Length: 2000, dtype: datetime64[ns]

# %% [markdown]
# Part 5 — Categorical Cleaning
# Q19. Clean City
# The City column contains values such as:
# Mumbai
# mumbai
# Mumbai
# mumbai
# Standardize the values so that logically identical cities are represented consistently.
# Then check the unique frequency distribution.
# Use: replace(), value_counts()

# %%
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Q20. Analyze Segment
# Check the frequency of:
# Retail
# SME
# Corporate
# Premium
# Also determine whether missing values exist.
# Then replace missing Segment values with the most appropriate category based on your
# analysis.

# %%
print(" finding frequency")
df["Segment"].value_counts() 
print(" number of missing values:")
print(df["Segment"].isnull().sum())
mode=df["Segment"].mode()[0] 
print("mode of this column:")
print(mode)
print(" after filling missing values with mode")
df["Segment"].fillna(mode)# as this is catagorial data  the missing values will be  filled using mode
# Out:
#  finding frequency
#  number of missing values:
# 100
# mode of this column:
# Premium
#  after filling missing values with mode
# 0             SME
# 1          Retail
# 2         Premium
# 3         Premium
# 4          Retail
#           ...
# 2035       Retail
# 2036    Corporate
# 2037       Retail
# 2038       Retail
# 2039       Retail
# Name: Segment, Length: 2000, dtype: object

# %% [markdown]
# Q21. Clean Active
# Active is supposed to be a binary column, but it contains:
# Yes
# No
# Y
# N
# YES
# NO
# yes
# no
# 1
# 0
# Transform these into a consistent representation:
# Yes
# No
# Then verify the result with value_counts().
# Use: replace(), value_counts()

# %%
df["Active"] = df["Active"].replace({
    "Y": "Yes",
    "YES": "Yes",
    "yes": "Yes",
    1: "Yes",
    "1": "Yes",
    "N": "No",
    "NO": "No",
    "no": "No",
    0: "No",
    "0": "No"
})

print("Unique values:")
print(df["Active"].unique())

print("\nValue counts:")
print(df["Active"].value_counts())
# Out:
# Unique values:
# ['Yes' 'No' nan]
#
# Value counts:
# Active
# Yes    1345
# No      597
# Name: count, dtype: int64

# %%
Q22. Clean Risk_Level
Check the distribution of:
High
Medium
Low
Verify whether missing values exist.qa
Then display the final class distribution.

# %%
print(f" distribution of each element in column is  :\n{df["Risk_Level"].value_counts()}")#to check distribution of each element in column
print(" number missing values in this column is :")
print(df["Risk_Level"].isnull().sum())
print(" final class distribution")
df["Risk_Level"].value_counts()
# Out:
#  distribution of each element in column is  :
# Risk_Level
# High      986
# Low       540
# Medium    474
# Name: count, dtype: int64
#  number missing values in this column is :
# 0
#  final cladd distribution
# Risk_Level
# High      986
# Low       540
# Medium    474
# Name: count, dtype: int64

# %% [markdown]
# Part 6 — Column Transformation
# Q23. Rename columns
# Rename these columns:
# Customer_ID → Customer_ID
# Annual_Income → AnnualIncome
# Account_Balance → AccountBalance
# Credit_Score → CreditScore
# Tenure_Years → Tenure
# Join_Date → CustomerJoinDate
# Risk_Level → RiskLevel
# Monthly_Spend → MonthlySpend
# Satisfaction_Score → SatisfactionScore
# Use rename().

# %%
df.rename(columns={"Customer_ID":"Customer_ID","Account_Balance":"AccountBalance","Credit_Score":"CreditScore","Tenure_Years":"Tenure","Join_Date":"CustomerJoinDate"\
                    ,"Risk_Level":"RiskLevel","Monthly_Spend":"MonthlySpend","Satisfaction_Score":"SatisfactionScore"})
# Out:
#       Customer_ID   Age  Annual_Income  AccountBalance  CreditScore  Tenure  \
# 0          101317  55.0        44033.0       111350.85          772       3
# 1          101001  32.0       215546.0       254378.37          374       8
# 2          101069  23.0       226403.0       159975.42          668      12
# 3          101968  66.0        87824.0       295741.60          315      14
# 4          100530  67.0        31570.0       242423.78          370       4
# ...           ...   ...            ...             ...          ...     ...
# 2035       101131  42.0        88530.0       153490.72          677      12
# 2036       101295  31.0       205738.0       270989.40          392       8
# 2037       100861  25.0       211994.0       160507.65          737       8
# 2038       101460  64.0        30105.0        32117.15          794       8
# 2039       101127  55.0       248332.0       274980.99          783       6
#
# ...

# %% [markdown]
# Q24. Add a prefix
# Add:
# Customer_
# to every column.
# Example:
# Age
# becomes:
# Customer_Age
# Use: add_prefix()

# %%
df.add_prefix("Customer_")
# Out:
#       Customer_Customer_ID  Customer_Age  Customer_Annual_Income  \
# 0                   101317          55.0                 44033.0
# 1                   101001          32.0                215546.0
# 2                   101069          23.0                226403.0
# 3                   101968          66.0                 87824.0
# 4                   100530          67.0                 31570.0
# ...                    ...           ...                     ...
# 2035                101131          42.0                 88530.0
# 2036                101295          31.0                205738.0
# 2037                100861          25.0                211994.0
# 2038                101460          64.0                 30105.0
# 2039                101127          55.0                248332.0
#
#       Customer_Account_Balance  Customer_Credit_Score  Customer_Tenure_Years  \
# 0                    111350.85                    772                      3
# ...

# %%
Q25. Remove unnecessary column

Determine whether Customer_ID should be retained for analysis.
Create a cleaned DataFrame without the identifier column.
Use: drop()

# %%
df.drop(columns=["Customer_ID"])
# Out:
#        Age  Annual_Income  Account_Balance  Credit_Score  Tenure_Years  City  \
# 0     55.0        44033.0        111350.85           772             3  None
# 1     32.0       215546.0        254378.37           374             8  None
# 2     23.0       226403.0        159975.42           668            12  None
# 3     66.0        87824.0        295741.60           315            14  None
# 4     67.0        31570.0        242423.78           370             4  None
# ...    ...            ...              ...           ...           ...   ...
# 2035  42.0        88530.0        153490.72           677            12  None
# 2036  31.0       205738.0        270989.40           392             8  None
# 2037  25.0       211994.0        160507.65           737             8  None
# 2038  64.0        30105.0         32117.15           794             8  None
# 2039  55.0       248332.0        274980.99           783             6  None
#
# ...

# %% [markdown]
# Part 7 — Create New Columns
# Q26. Create Annual Income in Lakhs
# Create:
# Income_Lakhs
# using:
# AnnualIncome / 100000
# Then check the first 10 records.

# %%
df["Income_Lakhs"]=df["Annual_Income"]/100000
df.head(10)
# Out:
#    Customer_ID   Age  Annual_Income  Account_Balance  Credit_Score  \
# 0       101317  55.0        44033.0        111350.85           772
# 1       101001  32.0       215546.0        254378.37           374
# 2       101069  23.0       226403.0        159975.42           668
# 3       101968  66.0        87824.0        295741.60           315
# 4       100530  67.0        31570.0        242423.78           370
# 5       101334  68.0        37087.0        180084.44           738
# 6       100415  47.0        67229.0         99629.81           464
# 7       100983  65.0       139914.0         61030.94           554
# 8       100417  63.0       153267.0        221707.97           508
# 9       101472  42.0       139914.0         41126.84           556
#
#    Tenure_Years  City    Segment Channel  Join_Date Active Risk_Level  \
# 0             3  None        SME   Agent 2022-08-15    Yes        Low
# 1             8  None     Retail   Agent 2025-01-11    Yes       High
# ...

# %% [markdown]
# Q27. Create Monthly Income
# Create:
# MonthlyIncome
# using:
# AnnualIncome / 12
# Then create:
# Income_After_Spending
# using:
# MonthlyIncome - MonthlySpend

# %%
df["MonthlyIncome"]=df["Annual_Income"]/12#new column "MonthlyIncome" created
df["Income_After_Spending"]=df["MonthlyIncome"]-df["Monthly_Spend"] #new column "Income_After_Spending" created
print(df.head(10))# to verify new  columns
# Out:
#    Customer_ID   Age  Annual_Income  Account_Balance  Credit_Score  \
# 0       101317  55.0        44033.0        111350.85           772
# 1       101001  32.0       215546.0        254378.37           374
# 2       101069  23.0       226403.0        159975.42           668
# 3       101968  66.0        87824.0        295741.60           315
# 4       100530  67.0        31570.0        242423.78           370
# 5       101334  68.0        37087.0        180084.44           738
# 6       100415  47.0        67229.0         99629.81           464
# 7       100983  65.0       139914.0         61030.94           554
# 8       100417  63.0       153267.0        221707.97           508
# 9       101472  42.0       139914.0         41126.84           556
#
#    Tenure_Years  City    Segment Channel  Join_Date Active Risk_Level  \
# 0             3  None        SME   Agent 2022-08-15    Yes        Low
# 1             8  None     Retail   Agent 2025-01-11    Yes       High
# ...

# %% [markdown]
# Q28. Create Balance-to-Income Ratio
# Create:
# Balance_Income_Ratio
# using:
# AccountBalance / AnnualIncome
# Then inspect the first 10 rows.
# Think carefully about division by zero and missing values.

# %%
try:
    df["Balance_Income_Ratio"]=df["Account_Balance"]/df["Annual_Income"]
    print(df.head(10))
except Exception as e:
    print(e)
# Out:
#    Customer_ID   Age  Annual_Income  Account_Balance  Credit_Score  \
# 0       101317  55.0        44033.0        111350.85           772
# 1       101001  32.0       215546.0        254378.37           374
# 2       101069  23.0       226403.0        159975.42           668
# 3       101968  66.0        87824.0        295741.60           315
# 4       100530  67.0        31570.0        242423.78           370
# 5       101334  68.0        37087.0        180084.44           738
# 6       100415  47.0        67229.0         99629.81           464
# 7       100983  65.0       139914.0         61030.94           554
# 8       100417  63.0       153267.0        221707.97           508
# 9       101472  42.0       139914.0         41126.84           556
#
#    Tenure_Years  City    Segment Channel  Join_Date Active Risk_Level  \
# 0             3  None        SME   Agent 2022-08-15    Yes        Low
# 1             8  None     Retail   Agent 2025-01-11    Yes       High
# ...

# %% [markdown]
# Part 8 — Final Real-World Cleaning Challenge
# Q29. Prepare the ML-ready dataset
# Perform the following complete pipeline:
# 1. Load the dataset.
# 2. Inspect the first 10 rows.
# 3. Inspect the last 10 rows.
# 4. Inspect 10 random records.
# 5. Run info().
# 6. Check missing values.
# 7. Check duplicates.
# 8. Remove duplicates.
# 9. Clean all numeric columns.
# 10. Convert invalid numeric values to missing.
# 11. Fill numerical missing values appropriately.
# 12. Convert Join_Date to datetime.
# 13. Handle invalid dates.
# 14. Standardize categorical values.
# 15. Clean the binary Active column.
# 16. Rename the columns.
# 17. Remove unnecessary columns.
# 18. Verify the final datatypes.
# 19. Generate descriptive statistics.
# 20. Check categorical distributions.

# %%
print("loading dataset:")
import pandas as pd
df=pd.read_csv(r"C:\Users\jyoti\Downloads\customer_analytics.csv")
print(df)
print(" inspecting first 10 rowa")
print(df.head(10))
print("inspecting last 10 rowa")
print(df.tail(10))
print(f" last 10 random records:\n{df.sample(10)}")
print("information  of the dataset")
print(df.info())
print("missing values")
print(df.isnull().sum())
print("checking duplicates")
print(df.duplicated().sum())
print("after removing duplicates")
df=df.drop_duplicates()
print(df)
print("1.cleaning numeric column")
print(" numeric column ")
num=df.select_dtypes(["number"])
print(num)
print(" finding missing value of each numeric columns")
print(num.isnull().sum())
print("filling missing values with median")
median=df["Satisfaction_Score"].median()
print("median of  Satisfaction_Score is" ,median)
df["Satisfaction_Score"]=df["Satisfaction_Score"].fillna(median)
print(f"after cleaning dataset by  replacing median in missing value{df['Satisfaction_Score']}")
print("finding object column in  data")
obj=df.select_dtypes(["object"]).columns
print(obj)
print(" suspecting  columns which contain invalid data")
for col in obj:
     print(f"{col}:")
     print(df[col].unique())
print(" converting invalid values to missing values in  columns df['Age'],df['Credit_Score'],df['Transactions]") 
df["Age"]=pd.to_numeric(df["Age"],errors="coerce")
df["Credit_Score"]=pd.to_numeric(df["Credit_Score"],errors="coerce")
df["Transactions"]=pd.to_numeric(df["Transactions"],errors="coerce")
print(f'{df["Age"]}\n{df["Credit_Score"]}\n{df["Transactions"]}\n')
print( " median of each  above column to  fill the missing values")
median_creditscore=df["Credit_Score"].median()
median_Age=df["Age"].median()
median_Transactions=df["Transactions"].median()
print("filling missing values of  column with its respective values")
df["Credit_Score"]=df["Credit_Score"].fillna(median_creditscore)
df["Age"]=df["Age"].fillna(median_Age)
df["Transactions"]=df["Transactions"].fillna(median_Transactions)
print(" after filling missing value of column age, transaction and ctreditscore")
print(df["Age"])
print(df["Transactions"])
print(df["Credit_Score"])
print("Converting Join_Date to datetime")
df["Join_Date"]=pd.to_datetime(df["Join_Date"],errors="coerce")
print(df["Join_Date"])
print(" finding catagorigal value")
df.columns
print('among columns previously we found catagorcal values are "City","Segment","Channel","Active","Risk_Level"')
print("value count of or distribution of values of each column")
print(df["City"].value_counts())
print(df["Segment"].value_counts())
print(df["Channel"].value_counts())
print("Standardize categorical values of each column")
print("already have unique values so no standardisation need in these catagorical value")
print(" Renaming columns")
df=df.rename(columns={"Customer_ID":"customer_id","Age":"age","Annual_Income" :"anuual_income","Account_Balance":"account_balance","Credit_Score":"credit_score","Tenure_Years":"tenure_year","City":"city","Segment":"segment" } )
print(df)
print("verifying final datatypes")
df.dtypes
print("escriptive statistics")
df.describe()
obj=df.select_dtypes(["object"])
print(f"checking catagirical data{obj}")
# Out:
# loading dataset:
#       Customer_ID   Age Annual_Income Account_Balance Credit_Score  \
# 0          101317  55.0       44033.0       111350.85          772
# 1          101001  32.0      215546.0       254378.37          374
# 2          101069  23.0      226403.0       159975.42          668
# 3          101968  66.0       87824.0        295741.6          315
# 4          100530  67.0       31570.0       242423.78          370
# ...           ...   ...           ...             ...          ...
# 2035       101131  42.0       88530.0       153490.72          677
# 2036       101295  31.0      205738.0        270989.4          392
# 2037       100861  25.0      211994.0       160507.65          737
# 2038       101460  64.0       30105.0        32117.15          794
# 2039       101127  55.0      248332.0       274980.99          783
#
#       Tenure_Years         City    Segment Channel            Join_Date  \
# ...

# %% [markdown]
# Q30 — Ultimate Pandas Cleaning Project
# You are a Data Scientist at a bank. Your raw customer dataset contains 2,000+ records with:
#
# • Missing values
# • Duplicate records
# • Invalid numerical values
# • Mixed datatypes
# • Invalid dates
# • Mixed date formats
# • Inconsistent categorical values
# • Binary text inconsistencies
# • Unnecessary identifier columns
# Your task is to produce a final clean analytical dataset.

# %% [markdown]
# Required workflow
# Step 1 — Load
# pd.read_csv()
# Step 2 — Inspect
# head()
# tail()
# sample()
# info()

# %%
import pandas as pd
pd.read_csv(r"C:\Users\jyoti\Downloads\customer_analytics.csv")
print("dataset loaded successfully")
print(df.info())
print(df.sample())
print(df.head())
print(df.tail())
print("dataset inspected successfully")
# Out:
# dataset loaded successfully
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 0 to 2039
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         2000 non-null   int64
#  1   age                 2000 non-null   float64
#  2   anuual_income       1893 non-null   object
#  3   account_balance     1875 non-null   object
#  4   credit_score        2000 non-null   float64
#  5   tenure_year         2000 non-null   int64
#  6   city                1920 non-null   object
#  7   segment             1900 non-null   object
#  8   Channel             2000 non-null   object
#  9   Join_Date           1875 non-null   datetime64[ns]
#  10  Active              1942 non-null   object
#  11  Risk_Level          2000 non-null   object
#  12  Monthly_Spend       1893 non-null   object
#  13  Transactions        2000 non-null   float64
#  14  Satisfaction_Score  2000 non-null   float64
# ...

# %% [markdown]
# Step 3 — Missing-value analysis
# isnull()
# isna()

# %%
df.isnull()
# Out:
#       customer_id    age  anuual_income  account_balance  credit_score  \
# 0           False  False          False            False         False
# 1           False  False          False            False         False
# 2           False  False          False            False         False
# 3           False  False          False            False         False
# 4           False  False          False            False         False
# ...           ...    ...            ...              ...           ...
# 2035        False  False          False            False         False
# 2036        False  False          False            False         False
# 2037        False  False          False            False         False
# 2038        False  False          False            False         False
# 2039        False  False          False            False         False
#
#       tenure_year   city  segment  Channel  Join_Date  Active  Risk_Level  \
# ...

# %% [markdown]
# Step 4 — Duplicate handling
# duplicated()
# drop_duplicates()

# %%
print(df.duplicated())
df=df.drop_duplicates()
print(df)
print("duplicate handelled successfully")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2035    False
# 2036    False
# 2037    False
# 2038    False
# 2039    False
# Length: 2000, dtype: bool
#       customer_id   age anuual_income account_balance  credit_score  \
# 0          101317  55.0       44033.0       111350.85         772.0
# 1          101001  32.0      215546.0       254378.37         374.0
# 2          101069  23.0      226403.0       159975.42         668.0
# 3          101968  66.0       87824.0        295741.6         315.0
# 4          100530  67.0       31570.0       242423.78         370.0
# ...           ...   ...           ...             ...           ...
# 2035       101131  42.0       88530.0       153490.72         677.0
# 2036       101295  31.0      205738.0        270989.4         392.0
# 2037       100861  25.0      211994.0       160507.65         737.0
# 2038       101460  64.0       30105.0        32117.15         794.0
# ...

# %%
Step 5 — Numeric cleaning
Clean:
age
Annual_Income
Account_Balance
Credit_Score
Monthly_Spend
Transactions
Satisfaction_Score

# %%
print(" to clean the  column first we need to convert the numeric values to proper numeric data type and invalid values in column to missing values")
df["age"]=pd.to_numeric(df["age"],errors="coerce")
df["anuual_income"]=pd.to_numeric(df["anuual_income"],errors="coerce")
df["credit_score"]=pd.to_numeric(df["credit_score"],errors="coerce")
df["Monthly_Spend "]=pd.to_numeric(df["Monthly_Spend"],errors="coerce")
df["Transactions"]=pd.to_numeric(df["Transactions"],errors="coerce")
df["Satisfaction_Score"]=pd.to_numeric(df["Satisfaction_Score"],errors="coerce")
print(df["age"])
print(df["anuual_income"])
print(df["credit_score"])
print(df["Monthly_Spend"])
print(df["Transactions"])
print(df["Satisfaction_Score"])
print("as there is no missing values found so no need to fill them")
# Out:
#  to clean the  column first we need to convert the numeric values to proper numeric data type and invalid values in column to missing values
# 0       55.0
# 1       32.0
# 2       23.0
# 3       66.0
# 4       67.0
#         ...
# 2035    42.0
# 2036    31.0
# 2037    25.0
# 2038    64.0
# 2039    55.0
# Name: age, Length: 2000, dtype: float64
# 0        44033.0
# 1       215546.0
# 2       226403.0
# 3        87824.0
# 4        31570.0
#           ...
# 2035     88530.0
# 2036    205738.0
# 2037    211994.0
# 2038     30105.0
# 2039    248332.0
# Name: anuual_income, Length: 2000, dtype: float64
# 0       772.0
# 1       374.0
# 2       668.0
# 3       315.0
# 4       370.0
#         ...
# 2035    677.0
# 2036    392.0
# 2037    737.0
# 2038    794.0
# 2039    783.0
# Name: credit_score, Length: 2000, dtype: float64
# 0       23066.19
# 1            NaN
# 2       28536.34
# 3       12869.71
# 4       34163.02
#           ...
# 2035     8455.42
# 2036    34087.69
# 2037    26518.74
# ...

# %%
Step 6 — Date cleaning
Clean:
Join_Date
using:
pd.to_datetime()

# %%
df["Join_Date"]=pd.to_datetime(df["Join_Date"],errors="coerce")
print(df["Join_Date"])
df["Join_Date"]=df["Join_Date"].ffill()# missing values is filled by its previos values using forward fill method
print(df["Join_Date"])
# Out:
# 0      2022-08-15 00:00:00.000
# 1      2025-01-11 00:00:00.000
# 2      2024-08-01 00:00:00.000
# 3      2021-05-15 00:00:00.000
# 4      2026-02-03 00:00:00.000
#                  ...
# 2035   2021-07-10 00:00:00.000
# 2036   2025-07-05 00:00:00.000
# 2037   2022-10-17 00:00:00.000
# 2038   2023-08-26 00:00:00.000
# 2039   2023-08-23 23:13:55.200
# Name: Join_Date, Length: 2000, dtype: datetime64[ns]
#  mean of this column is:
# 2023-08-23 23:13:55.200000
#  filling the missng values with mean
# 0      2022-08-15 00:00:00.000
# 1      2025-01-11 00:00:00.000
# 2      2024-08-01 00:00:00.000
# 3      2021-05-15 00:00:00.000
# 4      2026-02-03 00:00:00.000
#                  ...
# 2035   2021-07-10 00:00:00.000
# 2036   2025-07-05 00:00:00.000
# 2037   2022-10-17 00:00:00.000
# 2038   2023-08-26 00:00:00.000
# 2039   2023-08-23 23:13:55.200
# Name: Join_Date, Length: 2000, dtype: datetime64[ns]

# %%
Step 7 — Categorical cleaning
Clean:
City
Segment
Channel
Active
Risk_Level
replace()
value_counts()
fillna()

# %%
print(" distribution of  values of each column,; 'City','Segment','Channel','Active','Risk_Level'")
print(df["segment"].value_counts())
print(df["Channel"].value_counts())
print(df["Active"].value_counts())
print(df["City"].value_counts())
print(df["Risk_Level"].value_counts())
print(' as every column have unique values except"Active" we only need to clean this or standardise this')
df["Active"]=df["Active"].replace({"Y":"YES","N":"NO",1:"YES",0:"NO","no":"NO","yes":"YES"})
print(df["Active"])
print("finding missing values in this column")
print(df["Active"].isnull().sum())
print("filling missing values")
df["Active"]=df["Active"].ffill()
print(df["Active"])
# Out:
#  distribution of  values of each column,; 'City','Segment','Channel','Active','Risk_Level'
# segment
# Premium      516
# Retail       468
# Corporate    468
# SME          448
# Name: count, dtype: int64
# Channel
# Agent     530
# Online    497
# Branch    493
# Mobile    480
# Name: count, dtype: int64
# Active
# Yes    1288
# No      534
# NO       47
# YES      45
# 0        16
# 1        12
# Name: count, dtype: int64
# Channel
# Agent     530
# Online    497
# Branch    493
# Mobile    480
# Name: count, dtype: int64
# Risk_Level
# High      986
# Low       540
# Medium    474
# Name: count, dtype: int64
#  as every column have unique values except"Active" we only need to clean this or standardise this
# 0       Yes
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 2035     No
# 2036    Yes
# 2037    Yes
# 2038     No
# 2039    Yes
# Name: Active, Length: 2000, dtype: object
# finding missing values in this column
# 58
# filling missing values
# ...

# %%
Step 9 — Create analytical features
Create at least these:
Income_Lakhs
MonthlyIncome
Income_After_Spending
Balance_Income_Ratio

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\anoconda1\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File C:\anoconda1\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File C:\anoconda1\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %% [markdown]
# Step 10 — Final validation
# Your final DataFrame must pass these checks:
# No duplicate rows
# No invalid numeric values
# No unexpected object datatype in numeric columns
# No invalid dates
# No inconsistent Yes/No values
#
# Missing values handled
# Column names standardized
#
# Finally display:
# head()
# tail()
# sample()
# info()
# describe()
# value_counts()

# %%
print(df.head())
print(df.tail())
print(df.sample())
print(df.info())
print(df.describe())
print(df.value_counts())
# Out:
#    customer_id   age  anuual_income account_balance  credit_score  \
# 0       101317  55.0        44033.0       111350.85         772.0
# 1       101001  32.0       215546.0       254378.37         374.0
# 2       101069  23.0       226403.0       159975.42         668.0
# 3       101968  66.0        87824.0        295741.6         315.0
# 4       100530  67.0        31570.0       242423.78         370.0
#
#    tenure_year         city  segment Channel  Join_Date Active Risk_Level  \
# 0            3    Bangalore      SME   Agent 2022-08-15    Yes        Low
# 1            8        Delhi   Retail   Agent 2025-01-11    Yes       High
# 2           12      Chennai  Premium   Agent 2024-08-01     No     Medium
# 3           14       Mumbai  Premium   Agent 2021-05-15    Yes       High
# 4            4   bangalore    Retail   Agent 2026-02-03     No       High
#
#   Monthly_Spend  Transactions  Satisfaction_Score  Monthly_Spend   \
# ...
